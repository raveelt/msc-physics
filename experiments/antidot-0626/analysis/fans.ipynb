# %%
import plotting_tools as pt
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "/run/media/raveel/Crucial X9/qdg/qdev/experiments/antidot-0626/data/"

# %%
fig, ax = plt.subplots(1, 1, figsize=(25,10))

ymin = 1000
ymax = 8000


pt.plot_h5_2d(path+'dat106.h5', 'SET5_2d', gradient_axis=None, ax = ax, title = "topgate = 0V", ylabel = "field (mT)", xlabel = "backgate (mV)", yvals = np.linspace(8000, 0, 500), ylim = (ymin,ymax))
ax.invert_yaxis()

# %%
fig, ax = plt.subplots(1, 1, figsize=(25,10))

ymin = 200
ymax = 3000

pt.plot_h5_2d(path+'dat106.h5', 'SET5_2d', gradient_axis=None, ax = ax, title = "topgate = 0V", ylabel = "field (mT)", xlabel = "backgate (mV)", yvals = np.linspace(8000, 0, 500), ylim = (ymin,ymax), xlim = (-4000, 3000))
ax.invert_yaxis()


ax.axvline(x=-708, linestyle='--',color="red", ymin=0, ymax=1) #V_CNP

B_line = np.array([ymin, ymax])

V0 = -708
m = 0.16   # V/T

nus = np.arange(1,10,1)

for nu in nus:

    ax.plot(V0 + m*B_line*nu/2, B_line, color='red', linestyle='--')
    ax.plot(V0 - m*B_line*nu/2, B_line, color='red', linestyle='--')

# ax.plot(V0 + m*B_line*2, B_line, color='red', linestyle='--')
# ax.plot(V0 - m*B_line*2, B_line, color='red', linestyle='--')

# ax.plot(V0 + m*B_line*3, B_line, color='red', linestyle='--')
# ax.plot(V0 - m*B_line*3, B_line, color='red', linestyle='--')

# ax.plot(V0 + m*B_line*4, B_line, color='red', linestyle='--')
# ax.plot(V0 - m*B_line*4, B_line, color='red', linestyle='--')

# %%
fig, ax = plt.subplots(1, 1, figsize=(25,10))

ymin = 7500
ymax = 8000

pt.plot_h5_2d(path+'dat106.h5', 'SET5_2d', gradient_axis=None, ax = ax, title = "topgate = 0V", ylabel = "field (mT)", xlabel = "backgate (mV)", yvals = np.linspace(8000, 0, 500), ylim = (ymin,ymax))#, xlim = (-4000, 3000))
ax.invert_yaxis()


ax.axvline(x=-708, linestyle='--',color="red", ymin=0, ymax=1) #V_CNP

B_line = np.array([ymin, ymax])

V0 = -708
m = 0.155   # V/T

nus = np.arange(1,10,1)

for nu in nus:

    ax.plot(V0 + m*B_line*nu/2, B_line, color='red', linestyle='--')
    ax.plot(V0 - m*B_line*nu/2, B_line, color='red', linestyle='--')
